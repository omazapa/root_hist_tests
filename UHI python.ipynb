# %%
from hist import Hist, rebin
import matplotlib.pyplot as plt
import numpy as np
import hist

# %%
# Make a histogram
h = hist.Hist(hist.axis.Regular(20, 0, 20, name="x"))

# Fill it with events     mu  sd  
h.fill(x=np.random.normal(10, 10, 10000))
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f6442481410>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
h[5:15].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f6442022e50>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
