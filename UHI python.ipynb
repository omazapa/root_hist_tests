# %%
from hist import Hist, rebin
import matplotlib.pyplot as plt
import numpy as np
import hist
from ROOT import gRandom
# Out:
# Welcome to JupyROOT 6.29/01

# %%
gRandom.SetSeed()
# Out:
# 17.979629770852625

# %%
# Make a histogram
h = hist.Hist(hist.axis.Regular(20, 0, 20, name="x"))
data = []
for i in range(1000):
    data.append( gRandom.Gaus(10,10))
# Fill it with events     mu  sigma  
h.fill(x=data)
#h.fill(x=np.random.normal(10, 10, 10000))
h.plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f43d7e1b150>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]

# %%
h[5:15].plot()
# Out:
# [StairsArtists(stairs=<matplotlib.patches.StepPatch object at 0x7f43d7cfb090>, errorbar=<ErrorbarContainer object of 3 artists>, legend_artist=<ErrorbarContainer object of 3 artists>)]
